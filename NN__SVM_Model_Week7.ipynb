# %% [markdown]
# <a href="https://colab.research.google.com/github/APre203/MLTopic1/blob/main/NN__SVM_Model_Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pydub
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)

# %%
import os
import pathlib
import subprocess

import numpy as np
import pandas as pd
from scipy.io import wavfile

import argparse

import librosa
import librosa.feature
import soundfile as sf
import math
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

import json

# %%
csv_file = "/content/drive/MyDrive/stuttering_clips/fluencybank_labels.csv" #create dataframe for testing file
sep_file = "/content/drive/MyDrive/stuttering_clips/SEP-28k_labels.csv"
csv_df = pd.read_csv(csv_file, delimiter=",", encoding='utf-8')
sep_df = pd.read_csv(sep_file, delimiter=",", encoding='utf-8')

new_df = pd.concat([csv_df, sep_df], ignore_index=True)

csv_df = new_df

csv_df = csv_df.drop(['Start','Stop'],axis=1)

# print(len(csv_df))

# %% [markdown]
# ### MFCC AND MEL_SPECT

# %%
def mel_spectrogram(y, sr):
  mel_spect = librosa.feature.melspectrogram(y=y,sr=sr, n_mels=64)
  return mel_spect
def mfcc_converter(y,sr, n_fft=2048, hop_length=512, n_mfcc=13):
  mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, n_fft=n_fft, hop_length=hop_length)
  # mfcc_scaled = np.mean(mfcc.T, axis=0)
  mfcc = mfcc.T
  # print(mfcc_scaled.shape)
  # print(mfcc.shape)
  return mfcc

# %% [markdown]
# ### Creating the DataSet

# %%
from pandas._libs.lib import count_level_2d
import json

SAMPLERATE = 16000
SPECSHAPE = (64,94)
MFCCSHAPE = (13,)

JSON_PATH = "data.json"
JSON_TEST_PATH = "data_t.json"

def file_to_df(csv, num):
  test= int(num*0.2)
  data = {
      "Prolongation":[],
      "WordRep":[],
      "SoundRep":[],
      "Block":[],
      "Interjection":[],
      "Stutter":[],
      "spect":[],
      "mfcc":[],
      "natural":[],
      "total":[] #0 -> Stutter, 1 -> Prolongation, 2 -> WordRep, 3 -> SoundRep, 4 -> Block, 5 -> Interjection
  }
  test_data = {
      "Prolongation":[],
      "WordRep":[],
      "SoundRep":[],
      "Block":[],
      "Interjection":[],
      "Stutter":[],
      "spect":[],
      "mfcc":[],
      "natural":[],
      "total":[] #0 -> Stutter, 1 -> Prolongation, 2 -> WordRep, 3 -> SoundRep, 4 -> Block, 5 -> Interjection
  }
  #/content/drive/MyDrive/stuttering_clips/clips/stuttering-clips/clips/FluencyBank_010_0.wav
  # new_df = pd.DataFrame(columns=csv_df.columns)
  i = 0
  count = 0
  test_c = 0
  json_c = False
  for index, row in csv.iterrows():
    # find each wav file
    if count > num and test_c > test:
      break
    else:
      path_name = f'{row["Show"]}_{row["EpId"]}_{row["ClipId"]}.wav'
      p = f'/content/drive/MyDrive/stuttering_clips/clips/stuttering-clips/clips/'
      try:
        y, sr = sf.read(p + path_name)
        count += 1
      except:
        i+=1
        continue

      # print(count)
      # calculate spectro and mfcc for the wav fiel
      spectro = mel_spectrogram(y,sr)
      mfcc = mfcc_converter(y,sr)
      if spectro.shape != SPECSHAPE:
        continue
      else:
        if count > num:
          if not json_c:
            json_c = True
            with open(JSON_PATH, "w") as fp:
              # print(data)
              json.dump(data, fp, indent=4)
          data = test_data
        if row["Prolongation"] > 0 or row["WordRep"] > 0 or row["SoundRep"] > 0 or row["Block"] > 0 or row["Interjection"] > 0: # means they stuttered #row["NoStutteredWords"] >= 2:
          if row["Prolongation"] > 0:
            data["Prolongation"].append(1)
            data["Interjection"].append(0)
            data["Block"].append(0)
            data["SoundRep"].append(0)
            data["WordRep"].append(0)
            data["total"].append(1)
          elif row["WordRep"] > 0:
            data["WordRep"].append(1)
            data["Interjection"].append(0)
            data["Block"].append(0)
            data["SoundRep"].append(0)
            data["Prolongation"].append(0)
            data["total"].append(2)
          elif row["SoundRep"] > 0:
            data["SoundRep"].append(1)
            data["Interjection"].append(0)
            data["Block"].append(0)
            data["WordRep"].append(0)
            data["Prolongation"].append(0)
            data["total"].append(3)
          elif row["Block"] > 0:
            data["Block"].append(1)
            data["Interjection"].append(0)
            data["SoundRep"].append(0)
            data["WordRep"].append(0)
            data["Prolongation"].append(0)
            data["total"].append(4)
          else:
            data["Interjection"].append(1)
            data["Block"].append(0)
            data["SoundRep"].append(0)
            data["WordRep"].append(0)
            data["Prolongation"].append(0)
            data["total"].append(5)

          data["Stutter"].append(1) # did stutter
        else:
          data["Stutter"].append(0) # didnt stutter
          data["Interjection"].append(0)
          data["Block"].append(0)
          data["SoundRep"].append(0)
          data["WordRep"].append(0)
          data["Prolongation"].append(0)
          data["total"].append(0)

        if row["NaturalPause"] > 0:
          data["natural"].append(1)
        else:
          data["natural"].append(0)

        data["spect"].append(spectro.tolist())
        data["mfcc"].append(mfcc.tolist())

        if count > num:
          test_data = data
          test_c += 1
        # print(count, test_c)
        # nn_df = pd.concat([new_df, row], ignore_index=True)

        # new_df = nn_df  # Append the new row to the new DataFrame
        # retval_df = new_df
        # new_df = new_df.append(row, ignore_index=True)  # Append the new row to the new DataFrame TRY CHANGEING IT TO pd.concat
        # retval_df = new_df

  print(f'Number of times failed: {i}')

  with open(JSON_TEST_PATH, "w") as fp:
    json.dump(test_data, fp, indent=4)
  return None


def load_data(dataset_path): #Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
  with open(dataset_path, "r") as fp:
    data = json.load(fp)
    #compare1, compare2
  compare1 = "mfcc"
  # compare2 = "SoundRep"
  # inputs = np.array(data[compare1])
  # targets = np.array(data[compare])
  return data


def balanced(data, t): # 0 -> didnt stutter -- 1 -> stutter
  # count_stutter_0 = len(df[df["Stutter"] == 0])
  # count_stutter_1 = len(df[df["Stutter"] == 1])
  # number = min(count_stutter_0,count_stutter_1) # number of min(stutters,no-stutters)

  # balanced_df_stutter_0 = df[df["Stutter"] == 0].sample(n=math.ceil(number))
  # balanced_df_stutter_1 = df[df["Stutter"] == 1].sample(n=number)
  # retval_balanced = pd.concat([balanced_df_stutter_0, balanced_df_stutter_1])
  reval_data = {
      "spect":[],
      "mfcc":[],
      t:[]
  }
  count_stutter_0 = data[t].count(0)
  count_stutter_1 = data[t].count(1)

  number = min(count_stutter_0,count_stutter_1) # number of min(stutters,no-stutters)
  n0, n1 = number, number

  for i in range(len(data[t])):
    if n0 > 0 or n1 > 0:
      if n0 > 0 and data[t][i] == 0:
        n0 -= 1
        reval_data["spect"].append(data["spect"][i])
        reval_data["mfcc"].append(data["mfcc"][i])
        reval_data[t].append(data[t][i])

      elif n1 > 1 and data[t][i] == 1:
        n1 -= 1
        reval_data["spect"].append(data["spect"][i])
        reval_data["mfcc"].append(data["mfcc"][i])
        reval_data[t].append(data[t][i])
    else:
      break

  print(f'Length of total df is: {2*number}')
  return reval_data

# %%
csv_df = csv_df.sample(frac=1, random_state=42)
csv_sample = file_to_df(csv_df, 5000) #15000 of the wav files
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
# Number of times failed: 1505

# %%
import shutil

destination_folder = "/content/drive/MyDrive/"

shutil.copy(JSON_PATH, destination_folder)
shutil.copy(JSON_TEST_PATH, destination_folder)
# Out:
# '/content/drive/MyDrive/data_t.json'

# %% [markdown]
# ### Using the data

# %%
json_data = load_data("data.json")

# %%
data = balanced(json_data, "Stutter")
# Out:
# Length of total df is: 2190

# %%
# from sklearn.model_selection import train_test_split
# inputs, targets = load_data("data.json")
# inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

# %%
def plot_hist(hist):
  fig, axs = plt.subplots(2)
  # accuracy subplot
  axs[0].plot(hist.history["accuracy"], label="train accuracy")
  axs[0].plot(hist.history["val_accuracy"], label="test accuracy")
  axs[0].set_ylabel("Accuracy")
  axs[0].legend(loc="lower right")
  axs[0].set_title("Accuracy eval")


  # error subplot
  axs[1].plot(hist.history["loss"], label="train loss")
  axs[1].plot(hist.history["val_loss"], label="test loss")
  axs[1].set_ylabel("Loss")
  axs[1].set_xlabel("Epoch")
  axs[1].legend(loc="upper right")
  axs[1].set_title("Loss eval")

  plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D, Dropout
from tensorflow.keras.regularizers import l2
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

json_data = load_data("/content/drive/MyDrive/data.json")
def make_model(compare):
  data = json_data
  inputs = np.array(data["mfcc"])
  targets = np.array(data[compare])

  inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.2)
  print(f"Inputs_train: {inputs_train.shape[0]} -- Targets_train: {targets_train.shape[0]}")
  print(f"Inputs_test: {inputs_test.shape[0]} -- Targets_test: {targets_test.shape[0]}")
  print()
  print()
  yt_model = Sequential([
      Flatten(input_shape=(inputs.shape[1],inputs.shape[2])),

      # 1st Hidden Layer
      Dense(512, activation="relu", kernel_regularizer=l2(0.001)),
      Dropout(0.3),

      # 2nd Hidden Layer
      Dense(256, activation="relu", kernel_regularizer=l2(0.01)),
      Dropout(0.3),
      # 3rd Hidden Layer
      Dense(64, activation="relu", kernel_regularizer=l2(0.001)),
      # Dropout(0.3),
      Dense(32, activation="relu", kernel_regularizer=l2(0.001)),

      Dense(2, activation="softmax")

  ])

  optimizer = Adam(learning_rate=0.001)
  yt_model.compile(optimizer,
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])

  yt_model.summary()

  hist = yt_model.fit(inputs_train, targets_train, validation_data=(inputs_test,targets_test), epochs=100, batch_size=64)
  return yt_model, hist

# %%
model_prol, hist = make_model("Prolongation") #Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
plot_hist(hist)
# Out:
# Inputs_train: 3943 -- Targets_train: 3943
# Inputs_test: 986 -- Targets_test: 986
#
#
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 1222)              0
#
#  dense_30 (Dense)            (None, 512)               626176
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense
100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.6848 - accuracy: 0.7763 - val_loss: 0.9010 - val_accuracy: 0.6947
# Epoch 86/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.6508 - accuracy: 0.7827 - val_loss: 0.8819 - val_accuracy: 0.6927
# Epoch 87/100
# 62/62 [==============================] - 1s 20ms/step - loss: 0.6548 - accuracy: 0.7842 - val_loss: 0.8977 - val_accuracy: 0.6947
# Epoch 88/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6528 - accuracy: 0.7710 - val_loss: 0.8466 - val_accuracy: 0.7099
# Epoch 89/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6295 - accuracy: 0.7791 - val_loss: 0.8815 - val_accuracy: 0.7110
# Epoch 90/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6391 - accuracy: 0.7748 - val_loss: 0.8638 - val_accuracy: 0.6968
# Epoch 91/100
# 62/62 [==============================] - 1s 18ms/step - loss: 0.6238 - accuracy: 0.7687 - val_loss: 0.8609 - val_accuracy: 0.6927
# Epoch 92/100
# 62/62 [==============================] - 1s 18ms/step - loss: 0.6732 - accuracy: 0.7406 - val_loss: 0.8226 - val_accuracy: 0.7089
# Epoch 93/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6663 - accuracy: 0.7535 - val_loss: 0.7887 - val_accuracy: 0.7150
# Epoch 94/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6630 - accuracy: 0.7692 - val_loss: 0.8749 - val_accuracy: 0.7099
# Epoch 95/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6699 - accuracy: 0.7573 - val_loss: 0.8225 - val_accuracy: 0.7028
# Epoch 96/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6518 - accuracy: 0.7725 - val_loss: 0.8167 - val_accuracy: 0.7028
# Epoch 97/100
# 62/62 [==============================] - 1s 22ms/step - loss: 0.6284 - accuracy: 0.7738 - val_loss: 0.8821 - val_accuracy: 0.6968
# Epoch 98/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6289 - accuracy: 0.7801 - val_loss: 0.8517 - val_accuracy: 0.6897
# Epoch 99/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6297 - accuracy: 0.7756 - val_loss: 0.8482 - val_accuracy: 0.6897
# Epoch 100/100
# 62/62 [==============================] - 1s 19ms/step - loss: 0.6336 - accuracy: 0.7791 - val_loss: 0.8037 - val_accuracy: 0.6957

# %%
model_word, hist = make_model("WordRep") #Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
plot_hist(hist)
# Out:
# Inputs_train: 3943 -- Targets_train: 3943
# Inputs_test: 986 -- Targets_test: 986
#
#
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 1222)              0
#
#  dense_35 (Dense)            (None, 512)               626176
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_36 (Dense)            (None, 256)               131328
#
#  dense_37 (Dense)            (None, 64)                16448
#
#  dense_38 (Dense)            (None, 32)                2080
#
#  dense_39 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 776098 (2.96 MB)
# Trainable params: 776098 (2.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 62/62 [==============================] - 3s 21ms/step - loss: 13.1253 - accuracy: 0.7700 - val_loss: 4.7760 - val_accuracy: 0.8753
# Epoch 2/100
# 62/62 [==============================] - 1s 19ms/step - loss: 4.8309 - accuracy: 0.7811 - val_loss: 4.8845 - val_accuracy: 0.8793
# Epoch 3/100
# 62/62 [==============================] - 1s 16ms/step - loss: 4.1362 - accuracy: 0.7931 - val_loss: 3.5307 - val_accuracy: 0.8793
# Epoch 4/100
# 62/62 [==============================] - 1s 18ms/step - loss: 3.5494 - accuracy: 0.8095 - val_loss: 3.2164 - val_accuracy: 0.8266
# Epoch 5/100
# 62/62 [==============================] - 1s 16ms/step - loss: 3.2419 - accuracy: 0.8184 - val_loss: 3.0694 - val_accuracy: 0.8742
# Epoch 6/100
# 62/62 [==============================] - 1s 16ms/step - loss: 3.0483 - accuracy: 0.8372 - val_loss: 2.9710 - val_accuracy: 0.8144
# Epoch 7/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.8763 - accuracy: 0.8496 - val_loss: 2.8183 - val_accuracy: 0.8499
# Epoch 8/100
# 62/62 [==============================] - 1s 17ms/step - loss: 2
100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.4435 - accuracy: 0.8795 - val_loss: 0.5922 - val_accuracy: 0.8773
# Epoch 97/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3978 - accuracy: 0.8945 - val_loss: 0.6066 - val_accuracy: 0.8702
# Epoch 98/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4153 - accuracy: 0.8866 - val_loss: 0.6600 - val_accuracy: 0.8641
# Epoch 99/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4076 - accuracy: 0.8798 - val_loss: 0.6257 - val_accuracy: 0.8621
# Epoch 100/100
# 62/62 [==============================] - 1s 22ms/step - loss: 0.4179 - accuracy: 0.8823 - val_loss: 0.5601 - val_accuracy: 0.8702

# %%
model_sound, hist = make_model("SoundRep") #Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
plot_hist(hist)
# Out:
# Inputs_train: 3943 -- Targets_train: 3943
# Inputs_test: 986 -- Targets_test: 986
#
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_8 (Flatten)         (None, 1222)              0
#
#  dense_40 (Dense)            (None, 512)               626176
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_41 (Dense)            (None, 256)               131328
#
#  dense_42 (Dense)            (None, 64)                16448
#
#  dense_43 (Dense)            (None, 32)                2080
#
#  dense_44 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 776098 (2.96 MB)
# Trainable params: 776098 (2.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 62/62 [==============================] - 3s 29ms/step - loss: 9.7424 - accuracy: 0.8194 - val_loss: 6.9367 - val_accuracy: 0.8945
# Epoch 2/100
# 62/62 [==============================] - 1s 18ms/step - loss: 4.5854 - accuracy: 0.8313 - val_loss: 3.8815 - val_accuracy: 0.8945
# Epoch 3/100
# 62/62 [==============================] - 1s 17ms/step - loss: 3.5705 - accuracy: 0.8417 - val_loss: 3.1861 - val_accuracy: 0.8935
# Epoch 4/100
# 62/62 [==============================] - 1s 17ms/step - loss: 3.1662 - accuracy: 0.8641 - val_loss: 3.0327 - val_accuracy: 0.8955
# Epoch 5/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.9238 - accuracy: 0.8851 - val_loss: 2.8206 - val_accuracy: 0.8895
# Epoch 6/100
# 62/62 [==============================] - 1s 17ms/step - loss: 2.7643 - accuracy: 0.8871 - val_loss: 2.6957 - val_accuracy: 0.8722
# Epoch 7/100
# 62/62 [==============================] - 1s 18ms/step - loss: 2.6244 - accuracy: 0.8909 - val_loss: 2.5846 - val_accuracy: 0.8945
# Epoch 8/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.4696 - accuracy: 0.8945 - val_loss: 2.4219 - val_accuracy: 0.8925
# Epoch 9/100
# 62/62 [==============================] - 1s 17ms/step - loss: 2.3479 - accuracy: 0.8927 - val_loss: 2.3131 - val_accuracy: 0.8935
# Epoch 10/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.2480 - accuracy: 0.8940 - val_loss: 2.2539 - val_accuracy: 0.8631
# Epoch 11/100
# 62/62 [==============================] - 1s 19ms/step - loss: 2.1087 - accuracy: 0.9046 - val_loss: 2.1184 - val_accuracy: 0.8925
# Epoch 12/100
# 62/62 [==============================] - 1s 24ms/step - loss: 2.0230 - accuracy: 0.8988 - val_loss: 2.0296 - val_accuracy: 0.8905
# Epoch 13/100
# 62/62 [==============================] - 2s 24ms/step - loss: 1.9194 - accuracy: 0.9054 - val_loss: 1.9468 - val_accuracy: 0.8925
# Epoch 14/100
# 62/62 [==============================] - 2s 24ms/step - loss: 1.8310 - accuracy: 0.9084 - val_loss: 1.8691 - val_accuracy: 0.8915
# Epoch 15/100
# 62/62 [==============================] - 1s 17ms/step - loss: 1.7603 - accuracy: 0.9013 - val_loss: 1.7953 - val_accuracy: 0.8955
# Epoch 16/100
# 62/62 [==============================] - 1s 16ms/step - loss: 1.6815 - accuracy: 0.9051 - val_loss: 1.7178 - val_accuracy: 0.8915
# Epoch 17/100
# 62/62 [==============================] - 1s 18ms/step - loss: 1.5980 - accuracy: 0.9112 - val_loss: 1.6484 - val_accuracy: 0.8935
# Epoch 18/100
# 62/62 [==============================] - 1s 18ms/step - loss: 1.5254 - accuracy: 0.9100 - val_loss: 1.6137 - val_accuracy: 0.8935
# Epoch 19/100
# 62/62 [==============================] - 1s 17ms/step - loss: 1
100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3845 - accuracy: 0.9161 - val_loss: 0.5144 - val_accuracy: 0.8834
# Epoch 80/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3793 - accuracy: 0.9163 - val_loss: 0.4838 - val_accuracy: 0.8905
# Epoch 81/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3857 - accuracy: 0.9138 - val_loss: 0.4829 - val_accuracy: 0.8925
# Epoch 82/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3757 - accuracy: 0.9199 - val_loss: 0.4984 - val_accuracy: 0.8813
# Epoch 83/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3753 - accuracy: 0.9181 - val_loss: 0.4937 - val_accuracy: 0.8834
# Epoch 84/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3720 - accuracy: 0.9168 - val_loss: 0.5113 - val_accuracy: 0.8824
# Epoch 85/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3510 - accuracy: 0.9234 - val_loss: 0.6008 - val_accuracy: 0.8824
# Epoch 86/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3557 - accuracy: 0.9239 - val_loss: 0.5324 - val_accuracy: 0.8905
# Epoch 87/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3626 - accuracy: 0.9176 - val_loss: 0.5035 - val_accuracy: 0.8682
# Epoch 88/100
# 62/62 [==============================] - 1s 22ms/step - loss: 0.3780 - accuracy: 0.9176 - val_loss: 0.5043 - val_accuracy: 0.8763
# Epoch 89/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3694 - accuracy: 0.9176 - val_loss: 0.4992 - val_accuracy: 0.8895
# Epoch 90/100
# 62/62 [==============================] - 1s 23ms/step - loss: 0.3589 - accuracy: 0.9206 - val_loss: 0.4899 - val_accuracy: 0.8844
# Epoch 91/100
# 62/62 [==============================] - 1s 19ms/step - loss: 0.3793 - accuracy: 0.9082 - val_loss: 0.4580 - val_accuracy: 0.8864
# Epoch 92/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3643 - accuracy: 0.9166 - val_loss: 0.4794 - val_accuracy: 0.8864
# Epoch 93/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3618 - accuracy: 0.9135 - val_loss: 0.4800 - val_accuracy: 0.8864
# Epoch 94/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3468 - accuracy: 0.9122 - val_loss: 0.4896 - val_accuracy: 0.8742
# Epoch 95/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3441 - accuracy: 0.9150 - val_loss: 0.4463 - val_accuracy: 0.8884
# Epoch 96/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3684 - accuracy: 0.9100 - val_loss: 0.4573 - val_accuracy: 0.8793
# Epoch 97/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3706 - accuracy: 0.9084 - val_loss: 0.4294 - val_accuracy: 0.8905
# Epoch 98/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3690 - accuracy: 0.9044 - val_loss: 0.4465 - val_accuracy: 0.8864
# Epoch 99/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.3706 - accuracy: 0.9082 - val_loss: 0.4532 - val_accuracy: 0.8895
# Epoch 100/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3671 - accuracy: 0.9095 - val_loss: 0.4270 - val_accuracy: 0.8874

# %%
model_block, hist = make_model("Block") #Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
plot_hist(hist)
# Out:
# Inputs_train: 3943 -- Targets_train: 3943
# Inputs_test: 986 -- Targets_test: 986
#
#
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 1222)              0
#
#  dense_45 (Dense)            (None, 512)               626176
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_46 (Dense)            (None, 256)               131328
#
#  dense_47 (Dense)            (None, 64)                16448
#
#  dense_48 (Dense)            (None, 32)                2080
#
#  dense_49 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 776098 (2.96 MB)
# Trainable params: 776098 (2.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 62/62 [==============================] - 4s 28ms/step - loss: 10.9146 - accuracy: 0.7109 - val_loss: 6.2956 - val_accuracy: 0.8296
# Epoch 2/100
# 62/62 [==============================] - 1s 16ms/step - loss: 4.7345 - accuracy: 0.7355 - val_loss: 3.7238 - val_accuracy: 0.8286
# Epoch 3/100
# 62/62 [==============================] - 1s 18ms/step - loss: 3.8231 - accuracy: 0.7535 - val_loss: 3.4315 - val_accuracy: 0.8296
# Epoch 4/100
# 62/62 [==============================] - 1s 17ms/step - loss: 3
100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.4736 - accuracy: 0.8714 - val_loss: 0.7917 - val_accuracy: 0.7890
# Epoch 90/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.4557 - accuracy: 0.8740 - val_loss: 0.7638 - val_accuracy: 0.7941
# Epoch 91/100
# 62/62 [==============================] - 1s 18ms/step - loss: 0.4533 - accuracy: 0.8740 - val_loss: 0.7272 - val_accuracy: 0.7972
# Epoch 92/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.4780 - accuracy: 0.8696 - val_loss: 0.6987 - val_accuracy: 0.7840
# Epoch 93/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.4806 - accuracy: 0.8704 - val_loss: 0.7501 - val_accuracy: 0.8032
# Epoch 94/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4683 - accuracy: 0.8773 - val_loss: 0.7117 - val_accuracy: 0.7941
# Epoch 95/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.4690 - accuracy: 0.8684 - val_loss: 0.6960 - val_accuracy: 0.7880
# Epoch 96/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4471 - accuracy: 0.8755 - val_loss: 0.6545 - val_accuracy: 0.8205
# Epoch 97/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.4746 - accuracy: 0.8628 - val_loss: 0.7116 - val_accuracy: 0.8063
# Epoch 98/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4509 - accuracy: 0.8701 - val_loss: 0.7455 - val_accuracy: 0.8144
# Epoch 99/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4420 - accuracy: 0.8714 - val_loss: 0.7630 - val_accuracy: 0.8043
# Epoch 100/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.4470 - accuracy: 0.8669 - val_loss: 0.6874 - val_accuracy: 0.8043

# %%
model_inter, hist = make_model("Interjection") #Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
plot_hist(hist)
# Out:
# Inputs_train: 3943 -- Targets_train: 3943
# Inputs_test: 986 -- Targets_test: 986
#
#
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_10 (Flatten)        (None, 1222)              0
#
#  dense_50 (Dense)            (None, 512)               626176
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_51 (Dense)            (None, 256)               131328
#
#  dense_52 (Dense)            (None, 64)                16448
#
#  dense_53 (Dense)            (None, 32)                2080
#
#  dense_54 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 776098 (2.96 MB)
# Trainable params: 776098 (2.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 62/62 [==============================] - 3s 30ms/step - loss: 13.2432 - accuracy: 0.8258 - val_loss: 4.5591 - val_accuracy: 0.9158
# Epoch 2/100
# 62/62 [==============================] - 2s 24ms/step - loss: 4.5909 - accuracy: 0.8471 - val_loss: 3.7160 - val_accuracy: 0.9158
# Epoch 3/100
# 62/62 [==============================] - 1s 18ms/step - loss: 3.7061 - accuracy: 0.8638 - val_loss: 3.4314 - val_accuracy: 0.8742
# Epoch 4/100
# 62/62 [==============================] - 1s 16ms/step - loss: 3.4161 - accuracy: 0.8844 - val_loss: 3.2034 - val_accuracy: 0.9148
# Epoch 5/100
# 62/62 [==============================] - 1s 17ms/step - loss: 3.2000 - accuracy: 0.8930 - val_loss: 3.0694 - val_accuracy: 0.9138
# Epoch 6/100
# 62/62 [==============================] - 1s 16ms/step - loss: 3.0565 - accuracy: 0.8945 - val_loss: 3.1265 - val_accuracy: 0.9158
# Epoch 7/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.9414 - accuracy: 0.8973 - val_loss: 2.8614 - val_accuracy: 0.9087
# Epoch 8/100
# 62/62 [==============================] - 1s 17ms/step - loss: 2.7603 - accuracy: 0.9100 - val_loss: 2.7969 - val_accuracy: 0.8976
# Epoch 9/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.6685 - accuracy: 0.9034 - val_loss: 2.6076 - val_accuracy: 0.9118
# Epoch 10/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.5556 - accuracy: 0.9064 - val_loss: 2.5745 - val_accuracy: 0.9158
# Epoch 11/100
# 62/62 [==============================] - 1s 17ms/step - loss: 2.4580 - accuracy: 0.9107 - val_loss: 2.4453 - val_accuracy: 0.9128
# Epoch 12/100
# 62/62 [==============================] - 1s 18ms/step - loss: 2.3486 - accuracy: 0.9135 - val_loss: 2.3177 - val_accuracy: 0.9148
# Epoch 13/100
# 62/62 [==============================] - 2s 25ms/step - loss: 2.2791 - accuracy: 0.9107 - val_loss: 2.2449 - val_accuracy: 0.9168
# Epoch 14/100
# 62/62 [==============================] - 1s 24ms/step - loss: 2
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_11 (Flatten)        (None, 1222)              0
#
#  dense_55 (Dense)            (None, 512)               626176
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_56 (Dense)            (None, 256)               131328
#
#  dense_57 (Dense)            (None, 64)                16448
#
#  dense_58 (Dense)            (None, 32)                2080
#
#  dense_59 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 776098 (2.96 MB)
# Trainable params: 776098 (2.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 62/62 [==============================] - 3s 28ms/step - loss: 9.7833 - accuracy: 0.5399 - val_loss: 4.5828 - val_accuracy: 0.6420
# Epoch 2/100
# 62/62 [==============================] - 1s 17ms/step - loss: 4.2631 - accuracy: 0.5858 - val_loss: 3.8310 - val_accuracy: 0.5345
# Epoch 3/100
# 62/62 [==============================] - 1s 16ms/step - loss: 3.7624 - accuracy: 0.6016 - val_loss: 3.6384 - val_accuracy: 0.4899
# Epoch 4/100
# 62/62 [==============================] - 1s 17ms/step - loss: 3.5235 - accuracy: 0.6094 - val_loss: 3.3341 - val_accuracy: 0.6552
# Epoch 5/100
# 62/62 [==============================] - 1s 16ms/step - loss: 3.2921 - accuracy: 0.6383 - val_loss: 3.1597 - val_accuracy: 0.6663
# Epoch 6/100
# 62/62 [==============================] - 1s 17ms/step - loss: 3.1025 - accuracy: 0.6508 - val_loss: 3.0166 - val_accuracy: 0.6460
# Epoch 7/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.9515 - accuracy: 0.6594 - val_loss: 2.8996 - val_accuracy: 0.6136
# Epoch 8/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.8161 - accuracy: 0.6523 - val_loss: 2.7629 - val_accuracy: 0.6379
# Epoch 9/100
# 62/62 [==============================] - 1s 17ms/step - loss: 2.6923 - accuracy: 0.6680 - val_loss: 2.6269 - val_accuracy: 0.6572
# Epoch 10/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.5779 - accuracy: 0.6645 - val_loss: 2.5877 - val_accuracy: 0.5649
# Epoch 11/100
# 62/62 [==============================] - 1s 19ms/step - loss: 2.4523 - accuracy: 0.6794 - val_loss: 2.4224 - val_accuracy: 0.6755
# Epoch 12/100
# 62/62 [==============================] - 1s 24ms/step - loss: 2.3420 - accuracy: 0.6954 - val_loss: 2.3224 - val_accuracy: 0.6582
# Epoch 13/100
# 62/62 [==============================] - 1s 24ms/step - loss: 2.2400 - accuracy: 0.6934 - val_loss: 2.2425 - val_accuracy: 0.6481
# Epoch 14/100
# 62/62 [==============================] - 1s 22ms/step - loss: 2.1496 - accuracy: 0.6969 - val_loss: 2.1846 - val_accuracy: 0.6217
# Epoch 15/100
# 62/62 [==============================] - 1s 16ms/step - loss: 2.0773 - accuracy: 0.7073 - val_loss: 2.0922 - val_accuracy: 0.6521
# Epoch 16/100
# 62/62 [==============================] - 1s 18ms/step - loss: 1.9903 - accuracy: 0.7086 - val_loss: 2.0205 - val_accuracy: 0.6542
# Epoch 17/100
# 62/62 [==============================] - 1s 17ms/step - loss: 1.9105 - accuracy: 0.7243 - val_loss: 1.9693 - val_accuracy: 0.6542
# Epoch 18/100
# 62/62 [==============================] - 1s 17ms/step - loss: 1.8255 - accuracy: 0.7350 - val_loss: 1.9120 - val_accuracy: 0.6491
# Epoch 19/100
# 62/62 [==============================] - 1s 16ms/step - loss: 1.7676 - accuracy: 0.7340 - val_loss: 1.8592 - val_accuracy: 0.6643
# Epoch 20/100
# 62/62 [==============================] - 1s 16ms/step - loss: 1.7002 - accuracy: 0.7459 - val_loss: 1.7911 - val_accuracy: 0.6673
# Epoch 21/100
# 62/62 [==============================] - 1s 16ms/step - loss: 1.6566 - accuracy: 0.7350 - val_loss: 1.7462 - val_accuracy: 0.6440
# Epoch 22/100
# 62/62 [==============================] - 1s 17ms/step - loss: 1.5794 - accuracy: 0.7548 - val_loss: 1.6894 - val_accuracy: 0.6633
# Epoch 23/100
# 62/62 [==============================] - 1s 17ms/step - loss: 1
100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6686 - accuracy: 0.7385 - val_loss: 0.9835 - val_accuracy: 0.6207
# Epoch 81/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6543 - accuracy: 0.7588 - val_loss: 0.9888 - val_accuracy: 0.6349
# Epoch 82/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6687 - accuracy: 0.7421 - val_loss: 0.9174 - val_accuracy: 0.6247
# Epoch 83/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6523 - accuracy: 0.7525 - val_loss: 0.8945 - val_accuracy: 0.6379
# Epoch 84/100
# 62/62 [==============================] - 1s 18ms/step - loss: 0.6326 - accuracy: 0.7712 - val_loss: 0.8796 - val_accuracy: 0.6339
# Epoch 85/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6261 - accuracy: 0.7586 - val_loss: 0.8753 - val_accuracy: 0.6471
# Epoch 86/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6272 - accuracy: 0.7634 - val_loss: 0.9230 - val_accuracy: 0.6176
# Epoch 87/100
# 62/62 [==============================] - 1s 20ms/step - loss: 0.6228 - accuracy: 0.7692 - val_loss: 0.8681 - val_accuracy: 0.6430
# Epoch 88/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6566 - accuracy: 0.7479 - val_loss: 0.8553 - val_accuracy: 0.6440
# Epoch 89/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6410 - accuracy: 0.7532 - val_loss: 0.8422 - val_accuracy: 0.6430
# Epoch 90/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.5853 - accuracy: 0.7852 - val_loss: 0.8855 - val_accuracy: 0.6450
# Epoch 91/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6315 - accuracy: 0.7652 - val_loss: 0.8736 - val_accuracy: 0.6400
# Epoch 92/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6488 - accuracy: 0.7553 - val_loss: 0.8035 - val_accuracy: 0.6389
# Epoch 93/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6402 - accuracy: 0.7542 - val_loss: 0.9261 - val_accuracy: 0.6349
# Epoch 94/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6273 - accuracy: 0.7510 - val_loss: 0.8459 - val_accuracy: 0.6450
# Epoch 95/100
# 62/62 [==============================] - 1s 16ms/step - loss: 0.6299 - accuracy: 0.7482 - val_loss: 0.9073 - val_accuracy: 0.6268
# Epoch 96/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6004 - accuracy: 0.7664 - val_loss: 0.9167 - val_accuracy: 0.6176
# Epoch 97/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.5959 - accuracy: 0.7735 - val_loss: 0.9697 - val_accuracy: 0.6430
# Epoch 98/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.5796 - accuracy: 0.7753 - val_loss: 0.8463 - val_accuracy: 0.6298
# Epoch 99/100
# 62/62 [==============================] - 1s 17ms/step - loss: 0.6025 - accuracy: 0.7530 - val_loss: 0.8599 - val_accuracy: 0.6339
# Epoch 100/100
# 62/62 [==============================] - 1s 21ms/step - loss: 0.5919 - accuracy: 0.7608 - val_loss: 0.8430 - val_accuracy: 0.6440

# %%
data_t = load_data("/content/drive/MyDrive/data_t.json")

# %%
def zeroone(array):
  if array[0] > 0.5:
    return 0
  return 1

# %%
# print(inputs.shape)
# model_prol , model_word , model_sound , model_block , model_inter
#Stutter,Prolongation,WordRep,SoundRep,Block,Interjection
inputs = np.array(data_t["mfcc"])
targets = np.array(data_t["Prolongation"])
tp, tw, ts, tb, ti, tstutter, tnat = np.array(data_t["Prolongation"]), np.array(data_t["WordRep"]), np.array(data_t["SoundRep"]), np.array(data_t["Block"]), np.array(data_t["Interjection"]), np.array(data_t["Stutter"]), np.array(data_t["natural"])
predicted_prol = model_prol.predict(inputs)
predicted_word = model_word.predict(inputs)
predicted_sound = model_sound.predict(inputs)
predicted_block= model_block.predict(inputs)
predicted_inter = model_inter.predict(inputs)
predicted_natural = model_natural.predict(inputs)

cp,cw,cs,cb,ci,cstut,cnat = 0,0,0,0,0,0,0

for pp,pw,ps,pb,pi,p,w,s,b,i,stut,pn,n in zip(predicted_prol, predicted_word,predicted_sound,predicted_block,predicted_inter, tp, tw, ts, tb, ti, tstutter, predicted_natural,tnat):
  pp,pw,ps,pb,pi,pn = zeroone(pp),zeroone(pw),zeroone(ps),zeroone(pb),zeroone(pi),zeroone(pn)

  # print(pp, pw, ps, pb, pi) ps, pb, pi -> 0

  if pp == p:
    cp += 1
  if pw == w:
    cw += 1
  if ps == s:
    cs += 1
  if pb == b:
    cb += 1
  if pi == i:
    ci += 1
  if pn == n:
    cnat += 1

  if (pp == 0 and pw == 0 and ps == 0 and pb == 0 and pi == 0 and stut == 0) or (pp == 1 or pw==1 or ps==1 or pb==1 or pi==1 and stut == 1):
    cstut += 1
  # sutter = pp or pw or ps or pb or pi

  # if sutter == r:
  #   correct += 1

print(f"Prolongation: {cp / len(targets)}")
print(f"WordRep: {cw / len(targets)}")
print(f"SoundRep: {cs / len(targets)}")
print(f"Block: {cb / len(targets)}")
print(f"Interjection: {ci / len(targets)}")
print(f"Natural: {cnat / len(targets)}")
print(f"Stutter: {cstut / len(targets)}")
# Out:
# 32/32 [==============================] - 0s 6ms/step
# 32/32 [==============================] - 0s 5ms/step
# 32/32 [==============================] - 0s 5ms/step
# 32/32 [==============================] - 0s 6ms/step
# 32/32 [==============================] - 0s 6ms/step
# 32/32 [==============================] - 0s 6ms/step
# Prolongation: 0.6623376623376623
# WordRep: 0.8701298701298701
# SoundRep: 0.8881118881118881
# Block: 0.8091908091908092
# Interjection: 0.9310689310689311
# Natural: 0.6543456543456544
# Stutter: 0.3726273726273726

# %% [markdown]
# ### SVM Model

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

data = load_data("/content/drive/MyDrive/data.json")

# %%
from sklearn.metrics import confusion_matrix
def svm_model():
  mfcc = np.array(data["mfcc"])
  stutter = np.array(data["Stutter"])

  X_train, X_test, y_train, y_test = train_test_split(mfcc, stutter, test_size = 0.2, random_state = 1)

  X_train = X_train.reshape(X_train.shape[0], -1)
  X_test = X_test.reshape(X_test.shape[0], -1)

  # print(X_train.shape)
  # print(X_test.shape)
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  # type(y_train)
  X_train=pd.DataFrame(X_train)
  y_train=pd.DataFrame(y_train)
  X_test=pd.DataFrame(X_test)


  model = svm.SVC(kernel = 'rbf', C = 1)
  model1 = model.fit(X_train,y_train)
  print(model1.score(X_train,y_train))
  predicted=model.predict(X_test)
  print(accuracy_score(y_test,predicted))

  return model

# %%
svm_stutter_model = svm_model()
# Out:
# 0.8002541296060991
# 0.7865853658536586

# %%
test_data = load_data("/content/drive/MyDrive/data_t.json")

# %%
mfcc = np.array(test_data["mfcc"])
stutter = np.array(test_data["Stutter"])

sc = StandardScaler()
mfcc = mfcc.reshape(mfcc.shape[0], -1)
mfcc = sc.fit_transform(mfcc)

mfcc = pd.DataFrame(mfcc)
predicted=svm_stutter_model.predict(mfcc)
print(accuracy_score(stutter,predicted))
# Out:
# 0.7742257742257742
